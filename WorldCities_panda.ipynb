# %%
###worldcitis

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./DS_2021/data/worldcities.csv')

# %%
data
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6600   77.2300        India   IN  IND
# 3           Mumbai       Mumbai  18.9667   72.8333        India   IN  IND
# 4           Manila       Manila  14.5958  120.9772  Philippines   PH  PHL
# ...            ...          ...      ...       ...          ...  ...  ...
# 26564         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 26565  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 26566  Cheremoshna  Cheremoshna  51.3894   30.0989      Ukraine   UA  UKR
# 26567    Ambarchik    Ambarchik  69.6510  162.3336       Russia   RU  RUS
# 26568      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                admin_name  capital  population          id
# ...

# %%
data.tail(10)
# Out:
#                city    city_ascii      lat       lng    country iso2 iso3  \
# 26559  Starorybnoye  Starorybnoye  72.7666  104.8000     Russia   RU  RUS
# 26560         Agapa         Agapa  71.4504   89.2500     Russia   RU  RUS
# 26561        Tukchi        Tukchi  57.3670  139.5000     Russia   RU  RUS
# 26562         Numto         Numto  63.6667   71.3333     Russia   RU  RUS
# 26563        Olenëk        Olenek  68.5250  112.4500     Russia   RU  RUS
# 26564          Nord          Nord  81.7166  -17.8000  Greenland   GL  GRL
# 26565   Timmiarmiut   Timmiarmiut  62.5333  -42.2167  Greenland   GL  GRL
# 26566   Cheremoshna   Cheremoshna  51.3894   30.0989    Ukraine   UA  UKR
# 26567     Ambarchik     Ambarchik  69.6510  162.3336     Russia   RU  RUS
# 26568       Nordvik       Nordvik  74.0165  111.5100     Russia   RU  RUS
#
#                                      admin_name capital  population  \
# 26559                        Krasnoyarskiy Kray     NaN        10.0
# ...

# %%
data.head(20)
# Out:
#             city    city_ascii      lat       lng        country iso2 iso3  \
# 0          Tokyo         Tokyo  35.6897  139.6922          Japan   JP  JPN
# 1        Jakarta       Jakarta  -6.2146  106.8451      Indonesia   ID  IDN
# 2          Delhi         Delhi  28.6600   77.2300          India   IN  IND
# 3         Mumbai        Mumbai  18.9667   72.8333          India   IN  IND
# 4         Manila        Manila  14.5958  120.9772    Philippines   PH  PHL
# 5       Shanghai      Shanghai  31.1667  121.4667          China   CN  CHN
# 6      São Paulo     Sao Paulo -23.5504  -46.6339         Brazil   BR  BRA
# 7          Seoul         Seoul  37.5833  127.0000   Korea, South   KR  KOR
# 8    Mexico City   Mexico City  19.4333  -99.1333         Mexico   MX  MEX
# 9      Guangzhou     Guangzhou  23.1288  113.2590          China   CN  CHN
# 10       Beijing       Beijing  39.9050  116.3914          China   CN  CHN
# ...

# %%
data.sample(10,random_state=10)
# Out:
#                    city        city_ascii      lat       lng         country  \
# 21378            Walmer            Walmer  51.2043    1.3985  United Kingdom
# 7560    Saint Ann’s Bay   Saint Ann's Bay  18.4350  -77.2017         Jamaica
# 25796       Brønnøysund       Bronnoysund  65.4749   12.2120          Norway
# 1673         Ichinomiya        Ichinomiya  35.3039  136.8031           Japan
# 2978          Letpandan         Letpandan  17.7866   95.7507           Burma
# 6954             Telavi            Telavi  41.9167   45.4833         Georgia
# 14949  Castelnau-le-Lez  Castelnau-le-Lez  43.6369    3.9019          France
# 24795    South Hooksett    South Hooksett  43.0337  -71.4256   United States
# 20024          Santiago          Santiago -14.1896  -75.7400            Peru
# 5674        Nagykanizsa       Nagykanizsa  46.4558   16.9975         Hungary
#
#       iso2 iso3     admin_name capital  population          id
# ...

# %%
data.shape
# Out:
# (26569, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26569 entries, 0 to 26568
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        26569 non-null  object
#  1   city_ascii  26569 non-null  object
#  2   lat         26569 non-null  float64
#  3   lng         26569 non-null  float64
#  4   country     26569 non-null  object
#  5   iso2        26538 non-null  object
#  6   iso3        26569 non-null  object
#  7   admin_name  26493 non-null  object
#  8   capital     7626 non-null   object
#  9   population  25596 non-null  float64
#  10  id          26569 non-null  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.2+ MB

# %%
data.describe().round(2)
# Out:
#             lat       lng   population            id
# count  26569.00  26569.00     25596.00  2.656900e+04
# mean      33.10    -11.36    162345.70  1.556097e+09
# std       22.39     73.95    899658.50  2.873890e+08
# min      -54.93   -179.59         0.00  1.004003e+09
# 25%       27.92    -78.78      9246.00  1.276656e+09
# 50%       40.22     -0.77     20079.50  1.643148e+09
# 75%       47.99     29.68     59369.25  1.840005e+09
# max       81.72    179.37  37977000.00  1.934000e+09

# %%
data.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
data['country'].count()
# Out:
# 26569

# %%
data[['country','city']]
# Out:
#            country         city
# 0            Japan        Tokyo
# 1        Indonesia      Jakarta
# 2            India        Delhi
# 3            India       Mumbai
# 4      Philippines       Manila
# ...            ...          ...
# 26564    Greenland         Nord
# 26565    Greenland  Timmiarmiut
# 26566      Ukraine  Cheremoshna
# 26567       Russia    Ambarchik
# 26568       Russia      Nordvik
#
# [26569 rows x 2 columns]

# %%
data.sum()
# Out:
# city          TokyoJakartaDelhiMumbaiManilaShanghaiSão Paulo...
# city_ascii    TokyoJakartaDelhiMumbaiManilaShanghaiSao Paulo...
# lat                                                 879308.0703
# lng                                                -301926.3864
# country       JapanIndonesiaIndiaIndiaPhilippinesChinaBrazil...
# iso3          JPNIDNINDINDPHLCHNBRAKORMEXCHNCHNEGYUSAINDRUST...
# population                                       4155400546.559
# id                                               41343950141859
# dtype: object

# %%
data.count()
# Out:
# city          26569
# city_ascii    26569
# lat           26569
# lng           26569
# country       26569
# iso2          26538
# iso3          26569
# admin_name    26493
# capital        7626
# population    25596
# id            26569
# dtype: int64

# %%
data.population.mean()
# Out:
# 162345.70036564308

# %%
data.population.describe().round(2)
# Out:
# count       25596.00
# mean       162345.70
# std        899658.50
# min             0.00
# 25%          9246.00
# 50%         20079.50
# 75%         59369.25
# max      37977000.00
# Name: population, dtype: float64

# %%
data.country.hist();

# %%
data.population.hist(bins=100, figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)  #usuwanie pustych wartości
# Out:
#                city    city_ascii      lat       lng      country iso2 iso3  \
# 0             Tokyo         Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1           Jakarta       Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2             Delhi         Delhi  28.6600   77.2300        India   IN  IND
# 3            Mumbai        Mumbai  18.9667   72.8333        India   IN  IND
# 4            Manila        Manila  14.5958  120.9772  Philippines   PH  PHL
# ...             ...           ...      ...       ...          ...  ...  ...
# 26058      Greytown      Greytown  10.9167  -83.7000    Nicaragua   NI  NIC
# 26061        Sayḩūt        Sayhut  15.2105   51.2454        Yemen   YE  YEM
# 26062    Río Cuarto    Rio Cuarto -33.1230  -64.3478    Argentina   AR  ARG
# 26063  La Esmeralda  La Esmeralda   3.1738  -65.5466    Venezuela   VE  VEN
# 26073       Hödrögö       Hodrogo  48.9664   96.7833     Mongolia   MN  MNG
#
#          admin_name  capital    population          id
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26569 entries, 0 to 26568
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        26569 non-null  object
#  1   city_ascii  26569 non-null  object
#  2   lat         26569 non-null  float64
#  3   lng         26569 non-null  float64
#  4   country     26569 non-null  object
#  5   iso2        26538 non-null  object
#  6   iso3        26569 non-null  object
#  7   admin_name  26493 non-null  object
#  8   capital     7626 non-null   object
#  9   population  25596 non-null  float64
#  10  id          26569 non-null  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.2+ MB

# %%
cleaned = data.dropna()  # usuwa braki w secie  , usuwa braki w tabelece gdzies jest dana warotsc jedna NaN

print("Przed 'dropna'", data.shape)
print("Po 'dropna'", cleaned.shape)
# Out:
# Przed 'dropna' (26569, 11)
# Po 'dropna' (6622, 11)

# %%
cleaned.population.hist(bins=100, figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
data['population'].hasnans  # czy ma wartosci puste
# Out:
# True

# %%
cleaned = data.dropna(subset=['population'])
cleaned.shape   # usuwa puste rekoedy gdzie sa putse wartosci w podanych atrybutach
# Out:
# (25596, 11)

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25596 entries, 0 to 26568
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        25596 non-null  object
#  1   city_ascii  25596 non-null  object
#  2   lat         25596 non-null  float64
#  3   lng         25596 non-null  float64
#  4   country     25596 non-null  object
#  5   iso2        25569 non-null  object
#  6   iso3        25596 non-null  object
#  7   admin_name  25551 non-null  object
#  8   capital     6653 non-null   object
#  9   population  25596 non-null  float64
#  10  id          25596 non-null  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.3+ MB

# %%
cleaned['population']
# Out:
# 0        37977000.0
# 1        34540000.0
# 2        29617000.0
# 3        23355000.0
# 4        23088000.0
#             ...
# 26564          10.0
# 26565          10.0
# 26566           0.0
# 26567           0.0
# 26568           0.0
# Name: population, Length: 25596, dtype: float64
